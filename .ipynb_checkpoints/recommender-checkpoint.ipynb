# %% [markdown]
# ### Imports

# %%
import pandas as pd
import ast
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from tqdm.notebook import tqdm, tnrange
tqdm.pandas()
import dateutil
import datetime

# %% [markdown]
# #### Create Dataset

# %%
df = pd.read_csv("./data.csv",index_col=0)

# %%
values = ['director_anchors','genre','star_anchs','summary_tokens']
for val in values:
  df[val]=df[val].apply(lambda x: ast.literal_eval(x) if type(x)==str else np.nan)

# %%
df.head()
# Out:
#                                          name            profile  \
# 0  Star Wars: Episode VII - The Force Awakens  /title/tt2488496/
# 1                           Avengers: Endgame  /title/tt4154796/
# 2                                      Avatar  /title/tt0499549/
# 3                               Black Panther  /title/tt1825683/
# 4                      Avengers: Infinity War  /title/tt4154756/
#
#                                              summary  \
# 0  Three decades after the Empire's defeat, a new...
# 1  After the devastating events of Avengers: Infi...
# 2  A paraplegic Marine dispatched to the moon Pan...
# 3  T'Challa, heir to the hidden but advanced king...
# 4  The Avengers and their allies must be willing ...
#
#                        director_anchors            release  \
# 0                    [/name/nm0009190/]   18 December 2015
# 1  [/name/nm0751577/, /name/nm0751648/]      26 April 2019
# 2                    [/name/nm0000116/]   18 December 2009
# 3                    [/name/nm3363032/]   16 February 2018
# 4  [/name/nm0751577/, /name/nm0751648/]      27 April 2018
#
#                           genre  \
# 0   [Action, Adventure, Sci-Fi]
# 1    [Action, Adventure, Drama]
# 2  [Action, Adventure, Fantasy]
# 3   [Action, Adventure, Sci-Fi]
# 4   [Action, Adventure, Sci-Fi]
#
#                                           star_anchs              main_prod  \
# 0  [/name/nm5397459/, /name/nm3915784/, /name/nm1...              Lucasfilm
# 1  [/name/nm0000375/, /name/nm0262635/, /name/nm0...         Marvel Studios
# 2  [/name/nm0941777/, /name/nm0757855/, /name/nm0...  Twentieth Century Fox
# 3  [/name/nm1569276/, /name/nm0430107/, /name/nm2...         Marvel Studios
# 4  [/name/nm0000375/, /name/nm1165110/, /name/nm0...         Marvel Studios
#
#    summary_len  word_count        date    datetime  year  month  \
# 0            2          34  2015-12-18  2015-12-18  2015     12
# 1            2          37  2019-04-26  2019-04-26  2019      4
# 2            1          27  2009-12-18  2009-12-18  2009     12
# 3            1          30  2018-02-16  2018-02-16  2018      2
# 4            1          32  2018-04-27  2018-04-27  2018      4
#
#                                       summary_tokens
# 0  [2, 132, 3784, 75, 14, 1563, 22, 18, 2143, 15,...
# 1  [2, 75, 14, 16737, 963, 16, 17380, 45, 18425, ...
# 2  [2, 21, 2258, 5106, 12964, 2061, 16520, 20, 14...
# 3  [2, 13, 38, 22, 10989, 531, 15, 7678, 20, 14, ...
# 4  [2, 14, 17380, 17, 66, 6255, 491, 44, 4452, 20...

# %%
"asdf"+"3433"
# Out:
# 'asdf3433'

# %%
bag_of_words = []
for row in df.itertuples():
  result = ""
  result+=row.director_anchors[0].replace("/name/nm","").replace("/","")
  for val in row.genre:
    val=val.replace("-","")
    result+=" "+val.lower()+" "
  for val in row.star_anchs:
    result+=" "+val.replace("/name/nm","").replace("/","")+" "
  result+=row.summary.lower()
  bag_of_words.append(result)

# %%
df['bag_of_words']=bag_of_words

# %%
df.head()
# Out:
#                                          name            profile  \
# 0  Star Wars: Episode VII - The Force Awakens  /title/tt2488496/
# 1                           Avengers: Endgame  /title/tt4154796/
# 2                                      Avatar  /title/tt0499549/
# 3                               Black Panther  /title/tt1825683/
# 4                      Avengers: Infinity War  /title/tt4154756/
#
#                                              summary  \
# 0  Three decades after the Empire's defeat, a new...
# 1  After the devastating events of Avengers: Infi...
# 2  A paraplegic Marine dispatched to the moon Pan...
# 3  T'Challa, heir to the hidden but advanced king...
# 4  The Avengers and their allies must be willing ...
#
#                        director_anchors            release  \
# 0                    [/name/nm0009190/]   18 December 2015
# 1  [/name/nm0751577/, /name/nm0751648/]      26 April 2019
# 2                    [/name/nm0000116/]   18 December 2009
# 3                    [/name/nm3363032/]   16 February 2018
# 4  [/name/nm0751577/, /name/nm0751648/]      27 April 2018
#
#                           genre  \
# 0   [Action, Adventure, Sci-Fi]
# 1    [Action, Adventure, Drama]
# 2  [Action, Adventure, Fantasy]
# 3   [Action, Adventure, Sci-Fi]
# 4   [Action, Adventure, Sci-Fi]
#
#                                           star_anchs              main_prod  \
# 0  [/name/nm5397459/, /name/nm3915784/, /name/nm1...              Lucasfilm
# 1  [/name/nm0000375/, /name/nm0262635/, /name/nm0...         Marvel Studios
# 2  [/name/nm0941777/, /name/nm0757855/, /name/nm0...  Twentieth Century Fox
# 3  [/name/nm1569276/, /name/nm0430107/, /name/nm2...         Marvel Studios
# 4  [/name/nm0000375/, /name/nm1165110/, /name/nm0...         Marvel Studios
#
#    summary_len  word_count        date    datetime  year  month  \
# 0            2          34  2015-12-18  2015-12-18  2015     12
# 1            2          37  2019-04-26  2019-04-26  2019      4
# 2            1          27  2009-12-18  2009-12-18  2009     12
# 3            1          30  2018-02-16  2018-02-16  2018      2
# 4            1          32  2018-04-27  2018-04-27  2018      4
#
#                                       summary_tokens  \
# 0  [2, 132, 3784, 75, 14, 1563, 22, 18, 2143, 15,...
# 1  [2, 75, 14, 16737, 963, 16, 17380, 45, 18425, ...
# 2  [2, 21, 2258, 5106, 12964, 2061, 16520, 20, 14...
# 3  [2, 13, 38, 22, 10989, 531, 15, 7678, 20, 14, ...
# 4  [2, 14, 17380, 17, 66, 6255, 491, 44, 4452, 20...
#
#                                         bag_of_words
# 0  0009190 action  adventure  scifi  5397459  391...
# 1  0751577 action  adventure  drama  0000375  026...
# 2  0000116 action  adventure  fantasy  0941777  0...
# 3  3363032 action  adventure  scifi  1569276  043...
# 4  0751577 action  adventure  scifi  0000375  116...

# %%
# instantiating and generating the count matrix
count = CountVectorizer()
count_matrix = count.fit_transform(df['bag_of_words'])

# # generating the cosine similarity matrix
# cosine_sim = cosine_similarity(count_matrix, count_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bad50cc6b336> in <module>
#       1 # instantiating and generating the count matrix
# ----> 2 count = CountVectorizer()
#       3 count_matrix = count.fit_transform(df['bag_of_words'])
#       4
#       5 # # generating the cosine similarity matrix
#
# NameError: name 'CountVectorizer' is not defined

# %% [markdown]
# #### Create Cosin Similarities

# %%
similarities = cosine_similarity(np.array(df['summary_tokens'].tolist(), dtype='float32'))

# %%
df=df.reset_index(drop=True)

# %%
#  defining the function that takes in movie title 
# as input and returns the top 10 recommended movies
def recommendations(unique_id, cosine_sim = similarities):

  # initializing the empty list of recommended movies
  recommended_movies = []

#     breakpoint()
  # gettin the index of the movie that matches the unique id
  idx = df[df.profile==unique_id].index[0]

  # creating a Series with the similarity scores in descending order
  score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

  # getting the indexes of the 10 most similar movies
  top_10_indexes = list(score_series.iloc[1:11].index)

  # populating the list with the titles of the best 10 matching movies
  for i in top_10_indexes:
    recommended_movies.append(list(df.index)[i])

  return recommended_movies

# %%
values = recommendations(df.profile[0])

# %%
for val in values:
  print(df.iloc[val].summary)
  print("=================")
# Out:
# Jonah suffers from an anxiety disorder which causes him not to speak. But when his grandfather Chuck shows up at his own funeral reception, things begin to take an interesting turn and ...
# =================
# Brewster seems to be an almost too perfect example of idyllic small-town America, with everyone living in peace and harmony. So when newcomer Whiley Pritcher starts up his own local cable ...
# =================
# A computer virus has invaded a virtual reality fighting game leaving a rebellious teen trapped within. Now the boy's father must enter the tainted program and battle his way through a deadly maze of martial arts fighters to save his son.
# =================
# Megan Brothers has it all: A wonderful family, great friends and a rewarding career. But when her perfect world falls apart, she discovers that putting the pieces back together is no easy ...
# =================
# Struggling artists in Los Angeles, from studio executive to homeless actor, compromise their identities and souls in search of their dreams and passions... Funny, realistic, and heartfelt.
# =================
# Macbeth and Macduff were agents of the dangerous kind- America and Britain's finest secret weapons. But when Macbeth and his (semi-platonic) partner Banquo are confronted by three witches ...
# =================
# While trying to save their childhood orphanage, Moe, Larry and Curly inadvertently stumble into a murder plot and wind up starring in a reality television show.
# =================
# Six eager students strike out to explore and record live footage of supernatural activity at an abandoned plantation, but one unsettled spirit gives them more than they asked for.
# =================
# El Rio is run by a corrupt oil baron who wants to get the rights to Sally Mae's ranch which is sitting on a rich oil field. He will stop at nothing to get it, she stands to lose everything ...
# =================
# A young woman must live with her father who she has not seen in 15 years. While she rekindles her relationship with her father, she discovers Lythorin, an elf, lives in the forest. She ...
# =================

# %%
df.iloc[values]
# Out:
#                                          name             profile  \
# 35185                              Speechless  /title/tt11106572/
# 48186                           Public Access   /title/tt0107895/
# 41655                             Sci-Fighter   /title/tt0390463/
# 33402                           On the Market   /title/tt1500845/
# 31514                        Hollywood Whores   /title/tt1709118/
# 39439  Macbeth 3000: This Time, It's Personal   /title/tt0482006/
# 1872                        The Three Stooges   /title/tt0383010/
# 21294                       The Final Project   /title/tt3758334/
# 18107                      Gunfight at El Rio   /title/tt4648270/
# 27561                         Unexpected Race   /title/tt2166289/
#
#                                                  summary  \
# 35185  Jonah suffers from an anxiety disorder which c...
# 48186  Brewster seems to be an almost too perfect exa...
# 41655  A computer virus has invaded a virtual reality...
# 33402  Megan Brothers has it all: A wonderful family,...
# 31514  Struggling artists in Los Angeles, from studio...
# 39439  Macbeth and Macduff were agents of the dangero...
# 1872   While trying to save their childhood orphanage...
# 21294  Six eager students strike out to explore and r...
# 18107  El Rio is run by a corrupt oil baron who wants...
# 27561  A young woman must live with her father who sh...
#
#                            director_anchors             release  \
# 35185                    [/name/nm4604171/]    20 November 2019
# 48186                    [/name/nm0001741/]        January 1993
# 41655                    [/name/nm0131064/]         17 May 2005
# 33402                    [/name/nm2728891/]                2009
# 31514                    [/name/nm2080488/]      20 August 2011
# 39439                    [/name/nm2054108/]        15 July 2005
# 1872   [/name/nm0268370/, /name/nm0268380/]       13 April 2012
# 21294                    [/name/nm6462306/]        4 March 2016
# 18107                    [/name/nm7293783/]         15 May 2008
# 27561                    [/name/nm4107137/]   30 September 2003
#
#                          genre  \
# 35185  [Comedy, Drama, Family]
# 48186        [Drama, Thriller]
# 41655         [Action, Sci-Fi]
# 33402        [Comedy, Romance]
# 31514   [Comedy, Drama, Music]
# 39439         [Action, Comedy]
# 1872          [Comedy, Family]
# 21294       [Horror, Thriller]
# 18107                [Western]
# 27561                  [Drama]
#
#                                               star_anchs  \
# 35185  [/name/nm11057944/, /name/nm2485463/, /name/nm...
# 48186  [/name/nm0549825/, /name/nm0930095/, /name/nm0...
# 41655  [/name/nm0933310/, /name/nm0001686/, /name/nm0...
# 33402  [/name/nm3220632/, /name/nm2893045/, /name/nm3...
# 31514  [/name/nm0489196/, /name/nm2478830/, /name/nm5...
# 39439  [/name/nm2054495/, /name/nm2053062/, /name/nm2...
# 1872   [/name/nm0005003/, /name/nm0224565/, /name/nm0...
# 21294  [/name/nm1967072/, /name/nm3259039/, /name/nm5...
# 18107  [/name/nm4613501/, /name/nm4656026/, /name/nm5...
# 27561  [/name/nm2168769/, /name/nm3014457/, /name/nm2...
#
#                        main_prod  summary_len  word_count        date  \
# 35185  Watershed Motion Pictures            2          33  2019-11-20
# 48186                 Cinemabeam            2          32  1993-01-17
# 41655           Gorilla Pictures            2          41  2005-05-17
# 33402  Southern Horizon Pictures            2          33  2009-01-17
# 31514            Palmarejo Films            2          27  2011-08-20
# 39439            SuperGun Cinema            2          29  2005-07-15
# 1872       Twentieth Century Fox            1          26  2012-04-13
# 21294   3rd Fathom Entertainment            1          29  2016-03-04
# 18107                    Thespis            2          41  2008-05-15
# 27561        Wolf Productions UT            3          35  2003-09-30
#
#          datetime  year  month  \
# 35185  2019-11-20  2019     11
# 48186  1993-01-17  1993      1
# 41655  2005-05-17  2005      5
# 33402  2009-01-17  2009      1
# 31514  2011-08-20  2011      8
# 39439  2005-07-15  2005      7
# 1872   2012-04-13  2012      4
# 21294  2016-03-04  2016      3
# 18107  2008-05-15  2008      5
# 27561  2003-09-30  2003      9
#
#                                           summary_tokens
# 35185  [2, 17800, 6586, 18, 37, 40, 10248, 7942, 56, ...
# 48186  [2, 24987, 2206, 20, 44, 40, 557, 266, 2107, 8...
# 41655  [2, 21, 1428, 6231, 63, 11469, 21, 6599, 2902,...
# 33402  [2, 13972, 1670, 63, 32, 65, 45, 21, 5934, 190...
# 31514  [2, 7587, 1542, 19, 1213, 1558, 15, 37, 1120, ...
# 39439  [2, 27580, 17, 1572, 43, 5386, 46, 5125, 16, 1...
# 1872   [2, 133, 749, 20, 2079, 66, 4292, 19492, 15, 1...
# 21294  [2, 490, 8705, 573, 3333, 70, 20, 8594, 17, 57...
# 18107  [2, 931, 4017, 25, 485, 34, 21, 11305, 1585, 3...
# 27561  [2, 21, 461, 524, 491, 515, 29, 36, 321, 72, 3...
